# %% [markdown]
# ## Listing Data(cvs) Appending
# **Author : Yoora Choi**

# %%
# import libraries
import pandas as pd
import glob as g
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Import files and sort them 
csv_files = sorted(g.glob("./*.csv"))

# %%
# Check row counts, and column counts in each csv file 
summary = []

for file in csv_files:
    df = pd.read_csv(file)
    summary.append({
        'file': file,
        'num_rows': df.shape[0],
        'num_columns': df.shape[1]
    })

summary_df = pd.DataFrame(summary)
summary_df
# Out:
#                         file  num_rows  num_columns
# 0   ./CRMLSListing202401.csv     27454           84
# 1   ./CRMLSListing202402.csv     27447           84
# 2   ./CRMLSListing202403.csv     32282           84
# 3   ./CRMLSListing202404.csv     36503           84
# 4   ./CRMLSListing202405.csv     38796           82
# 5   ./CRMLSListing202406.csv     35893           82
# 6   ./CRMLSListing202407.csv     36340           82
# 7   ./CRMLSListing202408.csv     35305           82
# 8   ./CRMLSListing202409.csv     34625           82
# 9   ./CRMLSListing202410.csv     34730           82
# 10  ./CRMLSListing202411.csv     25128           82
# 11  ./CRMLSListing202412.csv     19417           82
# 12  ./CRMLSListing202501.csv     37469           82
# 13  ./CRMLSListing202502.csv     33983           82
# 14  ./CRMLSListing202503.csv     38492           82
# 15  ./CRMLSListing202504.csv     40187           82
# 16  ./CRMLSListing202505.csv     40271           82
# 17  ./CRMLSListing202506.csv     26399           82
# 18  ./CRMLSListing202507.csv     27345           82
# 19  ./CRMLSListing202508.csv     25210           82
# 20  ./CRMLSListing202509.csv     26923           82
# 21  ./CRMLSListing202510.csv     27586           82
# 22  ./CRMLSListing202511.csv     20677           82
# 23  ./CRMLSListing202512.csv     18773           82
# 24  ./CRMLSListing202601.csv     35302           82
# 25  ./CRMLSListing202602.csv     32431           81
# 26  ./CRMLSListing202603.csv     38844           81

# %%
# Check row counts in each csv filetotal number of rows in all csv files
total = 0 
for f in csv_files:
    df = pd.read_csv(f)
    rows = len(df)
    total += rows

print(f"\nTotal number of rows(Before appending): {total:,}rows")
# Out:
# Total number of rows(Before appending): 853,812rows

# %%
# Appending csv files
df_merge = pd.concat(
    [pd.read_csv(f) for f in csv_files],
    ignore_index= True
)

# Export csv file
df_merge.to_csv("CRMLSListing_merged.csv", index= False)

# %%
# check row number after appending csv files
print(f"Total number of rows(After appending): {len(df_merge):,}rows")
# Out:
# Total number of rows(After appending): 853,812rows

# %%
# vaildation

# Row check
if total == len(df_merge):
    print("Row count matches")
else:
    print("Row count mismatch")

# Column check
if df_merge.shape[1] == summary_df['num_columns'].max():
    print("Column count matches expected")
else:
    print("Column count mismatch")
# Out:
# the total row # before and after appending is same (Appending success)
