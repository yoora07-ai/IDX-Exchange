# %% [markdown]
# # Listed Data EDA (Week2)
# Using the dataset filtered "PropertyType == Residential"
# Author : Yoora Choi

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Import listed data (2024.01-2026.03)
listed = pd.read_csv("/Users/yoorachoi/Python/IDX/Listing/data/CRMLSListing_merged.csv",  low_memory=False)

# %% [markdown]
# ## 1.Data overview

# %%
# Check data structure
listed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540612 entries, 0 to 540611
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             539845 non-null  float64
#  1   ListingKey                    540612 non-null  int64
#  2   ListAgentEmail                493182 non-null  object
#  3   CloseDate                     161735 non-null  object
#  4   ClosePrice                    141190 non-null  float64
#  5   ListAgentFirstName            536362 non-null  object
#  6   ListAgentLastName             540572 non-null  object
#  7   Latitude                      460444 non-null  float64
#  8   Longitude                     460444 non-null  float64
#  9   UnparsedAddress               539919 non-null  object
#  10  PropertyType                  540612 non-null  object
#  11  LivingArea                    540057 non-null  float64
#  12  ListPrice                     540612 non-null  float64
#  13  DaysOnMarket                  540612 non-null  int64
#  14  ListOfficeName                540612 non-null  object
#  15  BuyerOfficeName               152758 non-null  object
#  16  CoListOfficeName              121031 non-null  object
#  17  ListAgentFullName             540521 non-null  object
#  18  CoListAgentFirstName          120546 non-null  object
#  19  CoListAgentLastName           120946 non-null  object
#  20  BuyerAgentMlsId               154840 non-null  object
#  21  BuyerAgentFirstName           154237 non-null  object
#  22  BuyerAgentLastName            154947 non-null  object
#  23  FireplacesTotal               0 non-null       float64
#  24  AssociationFeeFrequency       231037 non-null  object
#  25  AboveGradeFinishedArea        0 non-null       float64
#  26  ListingKeyNumeric             540612 non-null  int64
#  27  MLSAreaMajor                  467425 non-null  object
#  28  TaxAnnualAmount               0 non-null       float64
#  29  CountyOrParish                540612 non-null  object
#  30  PropertyType.1                540612 non-null  object
#  31  MlsStatus                     540612 non-null  object
#  32  ElementarySchool              64355 non-null   object
#  33  ListAgentFirstName.1          536362 non-null  object
#  34  AttachedGarageYN              446096 non-null  object
#  35  ParkingTotal                  540592 non-null  float64
#  36  BuilderName                   25233 non-null   object
#  37  PropertySubType               539356 non-null  object
#  38  LotSizeAcres                  496003 non-null  float64
#  39  SubdivisionName               199023 non-null  object
#  40  BuyerOfficeAOR                142941 non-null  object
#  41  YearBuilt                     539679 non-null  float64
#  42  DaysOnMarket.1                540612 non-null  int64
#  43  BuyerAgencyCompensationType   79013 non-null   object
#  44  StreetNumberNumeric           539739 non-null  float64
#  45  LivingArea.1                  540057 non-null  float64
#  46  ListingId                     540612 non-null  object
#  47  BathroomsTotalInteger         540557 non-null  float64
#  48  City                          540037 non-null  object
#  49  BuyerAgencyCompensation       78993 non-null   float64
#  50  TaxYear                       0 non-null       float64
#  51  BuildingAreaTotal             48111 non-null   float64
#  52  BedroomsTotal                 540465 non-null  float64
#  53  ContractStatusChangeDate      534503 non-null  object
#  54  Longitude.1                   460444 non-null  float64
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         14001 non-null   object
#  57  PurchaseContractDate          263213 non-null  object
#  58  ListingContractDate           540612 non-null  object
#  59  BelowGradeFinishedArea        3023 non-null    float64
#  60  BusinessType                  0 non-null       float64
#  61  Latitude.1                    460444 non-null  float64
#  62  ListPrice.1                   540612 non-null  float64
#  63  StateOrProvince               540559 non-null  object
#  64  CoveredSpaces                 0 non-null       float64
#  65  MiddleOrJuniorSchool          64485 non-null   object
#  66  FireplaceYN                   540038 non-null  object
#  67  Stories                       445876 non-null  float64
#  68  HighSchool                    84456 non-null   object
#  69  Levels                        482090 non-null  object
#  70  ListAgentLastName.1           540572 non-null  object
#  71  CloseDate.1                   161735 non-null  object
#  72  LotSizeDimensions             28227 non-null   object
#  73  LotSizeArea                   496841 non-null  float64
#  74  MainLevelBedrooms             293647 non-null  float64
#  75  NewConstructionYN             503509 non-null  object
#  76  GarageSpaces                  510527 non-null  float64
#  77  HighSchoolDistrict            377873 non-null  object
#  78  PostalCode                    540599 non-null  object
#  79  BuyerOfficeName.1             152758 non-null  object
#  80  AssociationFee                410446 non-null  float64
#  81  LotSizeSquareFeet             496667 non-null  float64
#  82  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  83  UnparsedAddress.1             539919 non-null  object
# dtypes: float64(33), int64(4), object(47)
# memory usage: 346.5+ MB

# %%
# check the data structure
listed.head(5)
# Out:
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0          1340000.0  1074973329                    haleh360@Gmail.com
# 1          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 2          3150000.0  1074936537                      anader@dppre.com
# 3          3090000.0  1074917818                  QIANYU0607@GMAIL.COM
# 4         12725000.0  1074143166          jeff.williams@pacificsir.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 1       NaN         NaN              Renee              Chen  33.496363
# 2       NaN         NaN           Margaret             Nader  34.119345
# 3       NaN         NaN             QIANYU              GUAN  33.984057
# 4       NaN         NaN               Jeff          Williams  33.607583
#
#     Longitude                UnparsedAddress PropertyType  LivingArea  \
# 0 -118.408445  2220 Avenue Of The Stars 2704  Residential      1301.0
# 1 -117.691677                   16 Palisades  Residential      2788.0
# 2 -118.111254              1615 Waverly Road  Residential      3250.0
# 3 -117.802819         2250 Indian Creek Road  Residential      7456.0
# 4 -117.887743                317 E. Bayfront  Residential      2321.0
#
#     ListPrice  DaysOnMarket                    ListOfficeName BuyerOfficeName  \
# 0   1340000.0           127           Rodeo Realty- Brentwood             NaN
# 1   2500000.0             1  Your Home Sold Guaranteed Realty             NaN
# 2   3150000.0             1                           COMPASS             NaN
# 3   3090000.0             0   Signature One Realty Group, Inc             NaN
# 4  12725000.0             2    Pacific Sotheby's Int'l Realty             NaN
#
#   CoListOfficeName  ListAgentFullName CoListAgentFirstName  \
# 0              NaN  Haleh Dowlatshahi                  NaN
# 1              NaN         Renee Chen                  NaN
# 2              NaN     Margaret Nader                  NaN
# 3              NaN        QIANYU GUAN                  NaN
# 4              NaN      Jeff Williams                  NaN
#
#   CoListAgentLastName BuyerAgentMlsId BuyerAgentFirstName BuyerAgentLastName  \
# 0                 NaN             NaN                 NaN                NaN
# 1                 NaN             NaN                 NaN                NaN
# 2                 NaN             NaN                 NaN                NaN
# 3                 NaN             NaN                 NaN                NaN
# 4                 NaN             NaN                 NaN                NaN
#
#    FireplacesTotal AssociationFeeFrequency  AboveGradeFinishedArea  \
# 0              NaN                 Monthly                     NaN
# 1              NaN                 Monthly                     NaN
# 2              NaN                     NaN                     NaN
# 3              NaN                 Monthly                     NaN
# 4              NaN                     NaN                     NaN
#
#    ListingKeyNumeric                            MLSAreaMajor  TaxAnnualAmount  \
# 0         1074973329           C05 - Westwood - Century City              NaN
# 1         1074954552                      LNSLT - Salt Creek              NaN
# 2         1074936537                        655 - San Marino              NaN
# 3         1074917818                       616 - Diamond Bar              NaN
# 4         1074143166  N9 - Lower Newport Bay - Balboa Island              NaN
#
#   CountyOrParish PropertyType.1 MlsStatus ElementarySchool  \
# 0    Los Angeles    Residential   Pending              NaN
# 1         Orange    Residential    Active              NaN
# 2    Los Angeles    Residential    Active              NaN
# 3    Los Angeles    Residential    Active      Castle Rock
# 4         Orange    Residential    Active      Harbor View
#
#   ListAgentFirstName.1 AttachedGarageYN  ParkingTotal BuilderName  \
# 0                Haleh              NaN           0.0         NaN
# 1                Renee             True           3.0         NaN
# 2             Margaret             True           2.0         NaN
# 3               QIANYU             True           4.0         NaN
# 4                 Jeff             True           2.0         NaN
#
#          PropertySubType  LotSizeAcres                       SubdivisionName  \
# 0            Condominium        4.0831                                   NaN
# 1  SingleFamilyResidence        0.1217           Warmington Homes (BB) (BBW)
# 2  SingleFamilyResidence        0.2159                                   NaN
# 3  SingleFamilyResidence        1.3368                                   NaN
# 4  SingleFamilyResidence        0.0517  Balboa Island - Little Island (BALL)
#
#   BuyerOfficeAOR  YearBuilt  DaysOnMarket.1 BuyerAgencyCompensationType  \
# 0            NaN     1964.0             127                       Item1
# 1            NaN     1994.0               1                       Item1
# 2            NaN     1965.0               1                       Item1
# 3            NaN     2003.0               0                       Item1
# 4            NaN     2019.0               2                       Item1
#
#    StreetNumberNumeric  LivingArea.1   ListingId  BathroomsTotalInteger  \
# 0               2220.0        1301.0    24389291                    2.0
# 1                 16.0        2788.0  AR24091628                    3.0
# 2               1615.0        3250.0    P1-17547                    4.0
# 3               2250.0        7456.0  OC24091496                    9.0
# 4                317.0        2321.0  NP24085020                    4.0
#
#             City  BuyerAgencyCompensation  TaxYear  BuildingAreaTotal  \
# 0    Los Angeles                      2.0      NaN             1301.0
# 1  Laguna Niguel                      2.0      NaN                NaN
# 2     San Marino                      2.5      NaN                NaN
# 3    Diamond Bar                      2.0      NaN                NaN
# 4  Newport Beach                      2.0      NaN                NaN
#
#    BedroomsTotal ContractStatusChangeDate  Longitude.1  \
# 0            2.0               2024-05-07  -118.408445
# 1            4.0               2024-01-24  -117.691677
# 2            6.0               2024-01-12  -118.111254
# 3            6.0               2024-01-20  -117.802819
# 4            3.0               2024-01-12  -117.887743
#
#    ElementarySchoolDistrict CoBuyerAgentFirstName PurchaseContractDate  \
# 0                       NaN                   NaN           2024-05-07
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN                  NaN
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
#
#   ListingContractDate  BelowGradeFinishedArea  BusinessType  Latitude.1  \
# 0          2024-01-01                     NaN           NaN   34.052207
# 1          2024-01-24                     NaN           NaN   33.496363
# 2          2024-01-12                     NaN           NaN   34.119345
# 3          2024-01-20                     NaN           NaN   33.984057
# 4          2024-01-12                     NaN           NaN   33.607583
#
#    ListPrice.1 StateOrProvince  CoveredSpaces MiddleOrJuniorSchool  \
# 0    1340000.0              CA            NaN                  NaN
# 1    2500000.0              CA            NaN                  NaN
# 2    3150000.0              CA            NaN                  NaN
# 3    3090000.0              CA            NaN            Chaparral
# 4   12725000.0              CA            NaN       Corona Del Mar
#
#   FireplaceYN  Stories      HighSchool       Levels ListAgentLastName.1  \
# 0       False      1.0             NaN          One         Dowlatshahi
# 1        True      2.0             NaN          Two                Chen
# 2        True      2.0             NaN          Two               Nader
# 3        True      NaN     Diamond Bar  ThreeOrMore                GUAN
# 4        True      NaN  Corona Del Mar  ThreeOrMore            Williams
#
#   CloseDate.1 LotSizeDimensions  LotSizeArea  MainLevelBedrooms  \
# 0         NaN               NaN     177861.0                NaN
# 1         NaN               NaN       5300.0                0.0
# 2         NaN               NaN       9404.0                NaN
# 3         NaN               NaN      58232.0                1.0
# 4         NaN               NaN       2250.0                3.0
#
#   NewConstructionYN  GarageSpaces     HighSchoolDistrict PostalCode  \
# 0             False           NaN                    NaN      90067
# 1             False           3.0     Capistrano Unified      92677
# 2               NaN           2.0                    NaN      91108
# 3             False           4.0  Walnut Valley Unified      91765
# 4             False           2.0   Newport Mesa Unified      92662
#
#   BuyerOfficeName.1  AssociationFee  LotSizeSquareFeet  \
# 0               NaN         2105.00           177861.0
# 1               NaN          254.00             5300.0
# 2               NaN             NaN             9404.0
# 3               NaN          295.95            58232.0
# 4               NaN            0.00             2250.0
#
#    MiddleOrJuniorSchoolDistrict              UnparsedAddress.1
# 0                           NaN  2220 Avenue Of The Stars 2704
# 1                           NaN                   16 Palisades
# 2                           NaN              1615 Waverly Road
# 3                           NaN         2250 Indian Creek Road
# 4                           NaN                317 E. Bayfront

# %%
# Summary statistics for numerical variable
listed.describe()
# Out:
#        OriginalListPrice    ListingKey    ClosePrice       Latitude  \
# count       5.398450e+05  5.406120e+05  1.411900e+05  460444.000000
# mean        1.398189e+06  1.104832e+09  1.201480e+06      34.606384
# std         7.354788e+06  2.989437e+07  4.354100e+06       2.000012
# min         0.000000e+00  1.018357e+09  5.250000e+02    -117.472493
# 25%         5.850000e+05  1.077381e+09  6.000000e+05      33.740149
# 50%         8.490000e+05  1.104932e+09  8.500000e+05      34.053944
# 75%         1.389999e+06  1.126964e+09  1.350000e+06      34.478232
# max         1.390000e+09  1.156489e+09  8.200000e+08     737.000000
#
#            Longitude    LivingArea     ListPrice   DaysOnMarket  \
# count  460444.000000  5.400570e+05  5.406120e+05  540612.000000
# mean     -118.463944  1.979979e+03  1.314312e+06      19.139886
# std         3.555755  2.337340e+04  2.348640e+06      26.682084
# min      -159.475987  0.000000e+00  1.000000e+02     -58.000000
# 25%      -118.696760  1.247000e+03  5.800000e+05       5.000000
# 50%      -118.029501  1.669000e+03  8.450000e+05      11.000000
# 75%      -117.237676  2.300000e+03  1.375000e+06      22.000000
# max       329.000000  1.702132e+07  1.950000e+08     731.000000
#
#        FireplacesTotal  AboveGradeFinishedArea  ListingKeyNumeric  \
# count              0.0                     0.0       5.406120e+05
# mean               NaN                     NaN       1.104832e+09
# std                NaN                     NaN       2.989437e+07
# min                NaN                     NaN       1.018357e+09
# 25%                NaN                     NaN       1.077381e+09
# 50%                NaN                     NaN       1.104932e+09
# 75%                NaN                     NaN       1.126964e+09
# max                NaN                     NaN       1.156489e+09
#
#        TaxAnnualAmount  ParkingTotal  LotSizeAcres      YearBuilt  \
# count              0.0  5.405920e+05  4.960030e+05  539679.000000
# mean               NaN  7.618042e+00  6.518526e+01    1979.598326
# std                NaN  3.527765e+03  1.213267e+04      27.000918
# min                NaN -1.430000e+02  0.000000e+00    1776.000000
# 25%                NaN  2.000000e+00  1.200000e-01    1961.000000
# 50%                NaN  2.000000e+00  1.700000e-01    1980.000000
# 75%                NaN  3.000000e+00  3.137000e-01    2001.000000
# max                NaN  2.593669e+06  4.187292e+06    2028.000000
#
#        DaysOnMarket.1  StreetNumberNumeric  LivingArea.1  \
# count   540612.000000         5.397390e+05  5.400570e+05
# mean        19.139886         1.158825e+04  1.979979e+03
# std         26.682084         2.853986e+05  2.337340e+04
# min        -58.000000         0.000000e+00  0.000000e+00
# 25%          5.000000         9.750000e+02  1.247000e+03
# 50%         11.000000         3.266000e+03  1.669000e+03
# 75%         22.000000         1.204600e+04  2.300000e+03
# max        731.000000         7.954796e+07  1.702132e+07
#
#        BathroomsTotalInteger  BuyerAgencyCompensation  TaxYear  \
# count          540557.000000             78993.000000      0.0
# mean                2.626204               189.109913      NaN
# std                 3.256854              2340.716879      NaN
# min                 0.000000                 0.000000      NaN
# 25%                 2.000000                 2.000000      NaN
# 50%                 2.000000                 2.500000      NaN
# 75%                 3.000000                 2.500000      NaN
# max              2208.000000            200000.000000      NaN
#
#        BuildingAreaTotal  BedroomsTotal    Longitude.1  \
# count       48111.000000  540465.000000  460444.000000
# mean         2445.258652       3.222923    -118.463944
# std          2248.077581       1.186857       3.555755
# min             0.000000       0.000000    -159.475987
# 25%          1305.000000       2.000000    -118.696760
# 50%          1825.000000       3.000000    -118.029501
# 75%          2800.000000       4.000000    -117.237676
# max        123764.000000      94.000000     329.000000
#
#        ElementarySchoolDistrict  BelowGradeFinishedArea  BusinessType  \
# count                       0.0             3023.000000           0.0
# mean                        NaN               87.238574           NaN
# std                         NaN              360.500960           NaN
# min                         NaN                0.000000           NaN
# 25%                         NaN                0.000000           NaN
# 50%                         NaN                0.000000           NaN
# 75%                         NaN                0.000000           NaN
# max                         NaN             5000.000000           NaN
#
#           Latitude.1   ListPrice.1  CoveredSpaces        Stories  \
# count  460444.000000  5.406120e+05            0.0  445876.000000
# mean       34.606384  1.314312e+06            NaN       1.370991
# std         2.000012  2.348640e+06            NaN       0.483071
# min      -117.472493  1.000000e+02            NaN       1.000000
# 25%        33.740149  5.800000e+05            NaN       1.000000
# 50%        34.053944  8.450000e+05            NaN       1.000000
# 75%        34.478232  1.375000e+06            NaN       2.000000
# max       737.000000  1.950000e+08            NaN       2.000000
#
#         LotSizeArea  MainLevelBedrooms   GarageSpaces  AssociationFee  \
# count  4.968410e+05      293647.000000  510527.000000   410446.000000
# mean   4.692671e+04           2.046879       1.844685      271.152047
# std    2.178064e+06           6.442479       3.877160     2369.383731
# min    0.000000e+00           0.000000       0.000000        0.000000
# 25%    5.000000e+03           1.000000       1.000000        0.000000
# 50%    7.194000e+03           2.000000       2.000000      125.000000
# 75%    1.204800e+04           3.000000       2.000000      400.000000
# max    9.187423e+08        3333.000000     600.000000   968348.000000
#
#        LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict
# count       4.966670e+05                           0.0
# mean        4.103986e+05                           NaN
# std         2.079520e+07                           NaN
# min         0.000000e+00                           NaN
# 25%         5.227000e+03                           NaN
# 50%         7.405000e+03                           NaN
# 75%         1.360300e+04                           NaN
# max         7.638115e+09                           NaN

# %%
# Summary statistics for non-numerical variable
listed.describe(include = 'object')
# Out:
#                                   ListAgentEmail   CloseDate  \
# count                                     493182      161735
# unique                                     89565         906
# top     randy.anderson@richmondamericanhomes.com  2024-03-29
# freq                                        1091        1057
#
#        ListAgentFirstName ListAgentLastName   UnparsedAddress PropertyType  \
# count              536362            540572            539919       540612
# unique              17035             37396            474831            1
# top               Michael               Lee  5166 Via Portola  Residential
# freq                 6788              2636                12       540612
#
#        ListOfficeName BuyerOfficeName CoListOfficeName ListAgentFullName  \
# count          540612          152758           121031            540521
# unique          20688           13637             6147             86171
# top           Compass         Compass          Compass        Todd Myatt
# freq            38528           12158            14085              1133
#
#        CoListAgentFirstName CoListAgentLastName BuyerAgentMlsId  \
# count                120546              120946          154840
# unique                 7447               15339           70459
# top                 Michael               Myatt       NONMEMBER
# freq                   1775                1134            2409
#
#        BuyerAgentFirstName BuyerAgentLastName AssociationFeeFrequency  \
# count               154237             154947                  231037
# unique               13649              27863                       4
# top                General          NONMEMBER                 Monthly
# freq                  1980               2012                  216924
#
#              MLSAreaMajor CountyOrParish PropertyType.1 MlsStatus  \
# count              467425         540612         540612    540612
# unique               1108             63              1         5
# top     699 - Not Defined    Los Angeles    Residential    Active
# freq                61554         137333         540612    269890
#
#        ElementarySchool ListAgentFirstName.1 AttachedGarageYN BuilderName  \
# count             64355               536362           446096       25233
# unique             1424                17035                2        3797
# top               Other              Michael             True      Lennar
# freq              13248                 6788           349988        2356
#
#               PropertySubType SubdivisionName BuyerOfficeAOR  \
# count                  539356          199023         142941
# unique                     21           17297             66
# top     SingleFamilyResidence           Other       SanDiego
# freq                   394249            5430          11187
#
#        BuyerAgencyCompensationType   ListingId         City  \
# count                        79013      540612       540037
# unique                           3      540517         1208
# top                          Item1  NDP2501178  Los Angeles
# freq                         77938           4        27925
#
#        ContractStatusChangeDate CoBuyerAgentFirstName PurchaseContractDate  \
# count                    534503                 14001               263213
# unique                      844                  2755                  826
# top                  2024-04-30               Michael           2024-04-24
# freq                       2372                   191                  880
#
#        ListingContractDate StateOrProvince MiddleOrJuniorSchool FireplaceYN  \
# count               540612          540559                64485      540038
# unique                 821              29                  672           2
# top             2025-05-01              CA                Other        True
# freq                  1776          540404                 9878      348553
#
#        HighSchool  Levels ListAgentLastName.1 CloseDate.1 LotSizeDimensions  \
# count       84456  482090              540572      161735             28227
# unique        529      18               37396         906             11963
# top         Other     One                 Lee  2024-03-29            50x135
# freq         4107  277502                2636        1057               482
#
#        NewConstructionYN HighSchoolDistrict PostalCode BuyerOfficeName.1  \
# count             503509             377873     540599            152758
# unique                 2                451       4356             13637
# top                False              Other      92253           Compass
# freq              481718              44906       4006             12158
#
#        UnparsedAddress.1
# count             539919
# unique            474831
# top     5166 Via Portola
# freq                  12

# %% [markdown]
# ## 2. Missing data check(null)

# %%
# null count
null_count = listed.isnull().sum()

# null percentage (%)
null_percent = (listed.isnull().sum() / len(listed)) * 100

# data frame
null_summary = pd.DataFrame({
    'null_count': null_count,
    'null_percent': null_percent
}).sort_values(by='null_percent', ascending=False)

null_summary['null_percent'] = null_summary['null_percent'].round(2)
null_summary
# Out:
#                               null_count  null_percent
# TaxAnnualAmount                   540612        100.00
# FireplacesTotal                   540612        100.00
# ElementarySchoolDistrict          540612        100.00
# TaxYear                           540612        100.00
# BusinessType                      540612        100.00
# MiddleOrJuniorSchoolDistrict      540612        100.00
# CoveredSpaces                     540612        100.00
# AboveGradeFinishedArea            540612        100.00
# BelowGradeFinishedArea            537589         99.44
# CoBuyerAgentFirstName             526611         97.41
# BuilderName                       515379         95.33
# LotSizeDimensions                 512385         94.78
# BuildingAreaTotal                 492501         91.10
# ElementarySchool                  476257         88.10
# MiddleOrJuniorSchool              476127         88.07
# BuyerAgencyCompensation           461619         85.39
# BuyerAgencyCompensationType       461599         85.38
# HighSchool                        456156         84.38
# CoListAgentFirstName              420066         77.70
# CoListAgentLastName               419666         77.63
# CoListOfficeName                  419581         77.61
# ClosePrice                        399422         73.88
# BuyerOfficeAOR                    397671         73.56
# BuyerOfficeName                   387854         71.74
# BuyerOfficeName.1                 387854         71.74
# BuyerAgentFirstName               386375         71.47
# BuyerAgentMlsId                   385772         71.36
# BuyerAgentLastName                385665         71.34
# CloseDate                         378877         70.08
# CloseDate.1                       378877         70.08
# SubdivisionName                   341589         63.19
# AssociationFeeFrequency           309575         57.26
# PurchaseContractDate              277399         51.31
# MainLevelBedrooms                 246965         45.68
# HighSchoolDistrict                162739         30.10
# AssociationFee                    130166         24.08
# Stories                            94736         17.52
# AttachedGarageYN                   94516         17.48
# Longitude                          80168         14.83
# Longitude.1                        80168         14.83
# Latitude                           80168         14.83
# Latitude.1                         80168         14.83
# MLSAreaMajor                       73187         13.54
# Levels                             58522         10.83
# ListAgentEmail                     47430          8.77
# LotSizeAcres                       44609          8.25
# LotSizeSquareFeet                  43945          8.13
# LotSizeArea                        43771          8.10
# NewConstructionYN                  37103          6.86
# GarageSpaces                       30085          5.56
# ContractStatusChangeDate            6109          1.13
# ListAgentFirstName.1                4250          0.79
# ListAgentFirstName                  4250          0.79
# PropertySubType                     1256          0.23
# YearBuilt                            933          0.17
# StreetNumberNumeric                  873          0.16
# OriginalListPrice                    767          0.14
# UnparsedAddress.1                    693          0.13
# UnparsedAddress                      693          0.13
# City                                 575          0.11
# FireplaceYN                          574          0.11
# LivingArea                           555          0.10
# LivingArea.1                         555          0.10
# BedroomsTotal                        147          0.03
# ListAgentFullName                     91          0.02
# BathroomsTotalInteger                 55          0.01
# StateOrProvince                       53          0.01
# ListAgentLastName                     40          0.01
# ListAgentLastName.1                   40          0.01
# ParkingTotal                          20          0.00
# PostalCode                            13          0.00
# DaysOnMarket                           0          0.00
# PropertyType                           0          0.00
# ListPrice                              0          0.00
# ListingContractDate                    0          0.00
# PropertyType.1                         0          0.00
# ListOfficeName                         0          0.00
# ListingKeyNumeric                      0          0.00
# CountyOrParish                         0          0.00
# MlsStatus                              0          0.00
# ListingKey                             0          0.00
# ListingId                              0          0.00
# ListPrice.1                            0          0.00
# DaysOnMarket.1                         0          0.00

# %% [markdown]
# ## 3. Check duplicates

# %% [markdown]
# ### 3.1 duplicated columns

# %%
# check duplicate columns
pairs = []

for col in listed.columns:
    if '.' in col:
        base_col = col.split('.')[0]
        if base_col in listed.columns:
            pairs.append((base_col, col))

pairs
# Out:
# [('PropertyType', 'PropertyType.1'),
#  ('ListAgentFirstName', 'ListAgentFirstName.1'),
#  ('DaysOnMarket', 'DaysOnMarket.1'),
#  ('LivingArea', 'LivingArea.1'),
#  ('Longitude', 'Longitude.1'),
#  ('Latitude', 'Latitude.1'),
#  ('ListPrice', 'ListPrice.1'),
#  ('ListAgentLastName', 'ListAgentLastName.1'),
#  ('CloseDate', 'CloseDate.1'),
#  ('BuyerOfficeName', 'BuyerOfficeName.1'),
#  ('UnparsedAddress', 'UnparsedAddress.1')]

# %%
# Check if duplicate column pairs have identical values row-by-row
for base, dup in pairs:
    same_ratio = (listed[base] == listed[dup]).mean()
    print(f"{base} vs {dup}: {same_ratio:.2f}")
# Out:
# PropertyType vs PropertyType.1: 1.00
# ListAgentFirstName vs ListAgentFirstName.1: 0.99
# DaysOnMarket vs DaysOnMarket.1: 1.00
# LivingArea vs LivingArea.1: 1.00
# Longitude vs Longitude.1: 0.85
# Latitude vs Latitude.1: 0.85
# ListPrice vs ListPrice.1: 1.00
# ListAgentLastName vs ListAgentLastName.1: 1.00
# CloseDate vs CloseDate.1: 0.30
# BuyerOfficeName vs BuyerOfficeName.1: 0.28
# UnparsedAddress vs UnparsedAddress.1: 1.00

# %% [markdown]
# ### 3.2 duplicated rows

# %%
# check completely duplicated rows
listed[listed.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [OriginalListPrice, ListingKey, ListAgentEmail, CloseDate, ClosePrice, ListAgentFirstName, ListAgentLastName, Latitude, Longitude, UnparsedAddress, PropertyType, LivingArea, ListPrice, DaysOnMarket, ListOfficeName, BuyerOfficeName, CoListOfficeName, ListAgentFullName, CoListAgentFirstName, CoListAgentLastName, BuyerAgentMlsId, BuyerAgentFirstName, BuyerAgentLastName, FireplacesTotal, AssociationFeeFrequency, AboveGradeFinishedArea, ListingKeyNumeric, MLSAreaMajor, TaxAnnualAmount, CountyOrParish, PropertyType.1, MlsStatus, ElementarySchool, ListAgentFirstName.1, AttachedGarageYN, ParkingTotal, BuilderName, PropertySubType, LotSizeAcres, SubdivisionName, BuyerOfficeAOR, YearBuilt, DaysOnMarket.1, BuyerAgencyCompensationType, StreetNumberNumeric, LivingArea.1, ListingId, BathroomsTotalInteger, City, BuyerAgencyCompensation, TaxYear, BuildingAreaTotal, BedroomsTotal, ContractStatusChangeDate, Longitude.1, ElementarySchoolDistrict, CoBuyerAgentFirstName, PurchaseContractDate, ListingContractDate, BelowGradeFinishedArea, BusinessType, Latitude.1, ListPrice.1, StateOrProvince, CoveredSpaces, MiddleOrJuniorSchool, FireplaceYN, Stories, HighSchool, Levels, ListAgentLastName.1, CloseDate.1, LotSizeDimensions, LotSizeArea, MainLevelBedrooms, NewConstructionYN, GarageSpaces, HighSchoolDistrict, PostalCode, BuyerOfficeName.1, AssociationFee, LotSizeSquareFeet, MiddleOrJuniorSchoolDistrict, UnparsedAddress.1]
# Index: []

# %%
listed.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Analysis Summary (CRMLSListing data (2024.01-2026.03))
#
# ### 1. Basic Information
# - **Total Rows:** 540,611
# - **Total Columns:** 84
# - **Data Period:** January 2024 – March 2026
#
# ---
#
# ### 2. Column Structure
# - **Data Types:** float64(32), int64(4), object(48)
#
# ---
#
# ### 3. Missing Data
# #### Completely Empty Columns (100% Null) → Consider Dropping
# - `CoveredSpaces`, `MiddleOrJuniorSchoolDistrict`, `ElementarySchoolDistrict`, `AboveGradeFinishedArea`, `FireplacesTotal`
#
# #### High Missing Rate (90–100%)
# -`BelowGradeFinishedArea`(99.44%), `CoBuyerAgentFirstName`(97.41%), `BuilderName`(95.33%),`LotSizeDimensions` (94.78%)`,`BuildingAreaTotal`(91.10%)
#
# #### High Missing Rate (70–80%)
# - `CoListAgentFirstName` (80.05%), `CoListAgentLastName` (80.00%), `CoListOfficeName` (79.98%), `ClosePrice` (72.74%), `BuyerOfficeAOR` (72.66%), `BuyerOfficeName` (71.28%), `BuyerOfficeName.1` (71.28%), `AssociationFeeFrequency` (71.14%), `BuyerAgentFirstName` (71.11%), `BuyerAgentMlsId` (71.09%), `BuyerAgentLastName` (71.01%), `CloseDate` (70.06%), `CloseDate.1` (70.06%)
# - → Buyer-related columns are missing for non-closed listings, which is expected
#
# #### Moderate Missing Rate (10–70%)
# - `SubdivisionName` (66.61%), `PurchaseContractDate` (56.89%), `MainLevelBedrooms` (53.76%), `HighSchoolDistrict` (39.76%), `AttachedGarageYN` (34.09%), `AssociationFee` (32.32%), `Stories` (25.94%), `Levels` (19.22%), `GarageSpaces` (18.99%), `FireplaceYN` (14.35%), `NewConstructionYN` (13.44%), `Latitude` (13.11%), `Latitude.1` (13.11%), `Longitude` (13.03%), `Longitude.1` (13.03%), `LivingArea` (12.47%), `LivingArea.1` (12.47%), `PropertySubType` (12.20%), `BedroomsTotal` (12.07%), `MLSAreaMajor` (11.29%)
#
# #### Low Missing Rate (0–10%)
# - `LotSizeAcres` (9.55%), `LotSizeSquareFeet` (9.24%), `LotSizeArea` (9.11%), `ListAgentEmail` (8.60%), `BathroomsTotalInteger` (8.19%), `YearBuilt` (8.14%), `ParkingTotal` (6.13%), `ContractStatusChangeDate` (0.81%), `ListAgentFirstName` (0.59%), `ListAgentFirstName.1` (0.59%), `StreetNumberNumeric` (0.44%), `OriginalListPrice` (0.39%), `UnparsedAddress` (0.25%), `UnparsedAddress.1` (0.25%), `ListPrice` (0.25%), `ListPrice.1` (0.25%), `City` (0.11%), `ListAgentFullName` (0.03%), `PostalCode` (0.02%), `ListAgentLastName` (0.01%), `ListAgentLastName.1` (0.01%), `StateOrProvince` (0.01%), `CountyOrParish` (0.00%)
#
# #### No Missing Values
# - `DaysOnMarket`, `DaysOnMarket.1`, `PropertyType`, `PropertyType.1`, `ListingKey`, `ListingKeyNumeric`, `ListOfficeName`, `MlsStatus`, `ListingId`, `ListingContractDate`
#
# ---
#
# ### 4. Duplicate Columns (11 Pairs Found)
#
# | Same Value Ratio | Column Pairs |
# |-----------------|--------------|
# | 100% | `PropertyType` / `PropertyType.1`, `DaysOnMarket` / `DaysOnMarket.1`, `ListPrice` / `ListPrice.1`, `ListAgentLastName` / `ListAgentLastName.1`, `UnparsedAddress` / `UnparsedAddress.1` |
# | ~99% | `ListAgentFirstName` / `ListAgentFirstName.1` |
# | ~87–88% | `Latitude` / `Latitude.1`, `Longitude` / `Longitude.1`, `LivingArea` / `LivingArea.1` |
# | **~29–30%** | **`CloseDate` / `CloseDate.1`, `BuyerOfficeName` / `BuyerOfficeName.1`** ← Values differ, requires investigation |
#
# ---
#
# ### 5. Duplicate Rows
# - **Completely duplicated rows: 0**

# %% [markdown]
# ### 6. Key MLS Fields – Statistical Summary

# %%
# Numerical key fields summary, 50% = median
key_num_cols = ['OriginalListPrice','ListPrice', 'ClosePrice', 'LotSizeAcres', 'LivingArea', 'BedroomsTotal', 'BathroomsTotalInteger', 'DaysOnMarket', 'YearBuilt']
listed[key_num_cols].describe().round(2)
# Out:
#        OriginalListPrice     ListPrice    ClosePrice  LotSizeAcres  \
# count       5.398450e+05  5.406120e+05  1.411900e+05     496003.00
# mean        1.398189e+06  1.314312e+06  1.201480e+06         65.19
# std         7.354788e+06  2.348640e+06  4.354100e+06      12132.67
# min         0.000000e+00  1.000000e+02  5.250000e+02          0.00
# 25%         5.850000e+05  5.800000e+05  6.000000e+05          0.12
# 50%         8.490000e+05  8.450000e+05  8.500000e+05          0.17
# 75%         1.389999e+06  1.375000e+06  1.350000e+06          0.31
# max         1.390000e+09  1.950000e+08  8.200000e+08    4187292.00
#
#         LivingArea  BedroomsTotal  BathroomsTotalInteger  DaysOnMarket  \
# count    540057.00      540465.00              540557.00     540612.00
# mean       1979.98           3.22                   2.63         19.14
# std       23373.40           1.19                   3.26         26.68
# min           0.00           0.00                   0.00        -58.00
# 25%        1247.00           2.00                   2.00          5.00
# 50%        1669.00           3.00                   2.00         11.00
# 75%        2300.00           4.00                   3.00         22.00
# max    17021321.00          94.00                2208.00        731.00
#
#        YearBuilt
# count   539679.0
# mean      1979.6
# std         27.0
# min       1776.0
# 25%       1961.0
# 50%       1980.0
# 75%       2001.0
# max       2028.0

# %% [markdown]
# **Data Quality Issues Detected**
# - **ListPrice / ClosePrice / LivingArea:** Min = 0 and extremely high max values suggest outliers or data entry errors which, requires cleaning
# - **DaysOnMarket:** Negative min value (-58) is invalid, which requires investigation
# - **BedroomsTotal:** Max = 149 is likely an error
# - **BathroomsTotalInteger:** Max = 2,208 is clearly an error

# %%
# Categorical key fields summary
key_cat_cols = ['PropertyType', 'ListOfficeName']
listed[key_cat_cols].describe()
# Out:
#        PropertyType ListOfficeName
# count        540612         540612
# unique            1          20688
# top     Residential        Compass
# freq         540612          38528

# %%
# Categorical key fields - value counts
for col in key_cat_cols:
    print(f"\n--- {col} ---")
    print(listed[col].value_counts().head(15))
# Out:
# --- PropertyType ---
# PropertyType
# Residential    540612
# Name: count, dtype: int64
#
# --- ListOfficeName ---
# ListOfficeName
# Compass                                                  38528
# Coldwell Banker Realty                                   23896
# Keller Williams Realty                                    9445
# Berkshire Hathaway HomeServices California Properties     7136
# Intero Real Estate Services                               6221
# Real Broker                                               6040
# eXp Realty of California Inc                              5990
# First Team Real Estate                                    5985
# Equity Union                                              5156
# eXp Realty of California, Inc.                            4556
# The Agency                                                4464
# Century 21 Masters                                        3865
# Redfin Corporation                                        3680
# Sotheby's International Realty                            3555
# Coldwell Banker West                                      3299
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Next Steps
# 1. Drop 100% null columns: `CoveredSpaces`, `MiddleOrJuniorSchoolDistrict`, `ElementarySchoolDistrict`, `AboveGradeFinishedArea`, `FireplacesTotal`
# 2. Drop `.1` duplicate columns, but first investigate why `CloseDate` and `BuyerOfficeName` show only ~30% match
# 3. Determine how to handle missing values in Buyer-related columns
# 4. Reload CSV with explicit dtype specified for mixed-type columns: `ListAgentEmail`, `BuyerAgencyCompensationType`
# 5. Fix data types for the following columns:
#    - `CloseDate`, `CloseDate.1`, `PurchaseContractDate`, `ListingContractDate`, `ContractStatusChangeDate` : object → datetime
#    - `YearBuilt`, `BedroomsTotal`, `BathroomsTotalInteger`, `Stories`, `GarageSpaces`, `ParkingTotal`, `MainLevelBedrooms` : float64 → int64 (after handling nulls)
#    - `AttachedGarageYN`, `FireplaceYN`, `NewConstructionYN` : object → bool
